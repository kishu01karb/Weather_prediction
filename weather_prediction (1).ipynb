# %%
import pandas as pd
weather=pd.read_csv("weather.csv",index_col="DATE")

# %%
weather
# Out:
#                 STATION                              NAME  ACMH   ACSH   AWND  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0   90.0    NaN
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   20.0    NaN
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  80.0  100.0    NaN
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  10.0   20.0    NaN
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  30.0   10.0    NaN
# ...                 ...                               ...   ...    ...    ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN   9.62
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  12.08
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  14.99
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN  16.78
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US   NaN    NaN    NaN
#
#             FMTM  PGTM  PRCP  SNOW  SNWD  ...  WT11  WT13  WT14  WT15  WT16  \
# DATE                                      ...
# 1970-01-01   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   NaN  0.02   0.0   0.0  ...   NaN   NaN   NaN   NaN   1.0
# 1970-01-04   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 1970-01-05   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...  ...   ...   ...   ...   ...   ...
# 2022-10-17   NaN   NaN  0.08   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-18   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-19   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-20   NaN  10.0  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
# 2022-10-21   NaN   NaN  0.00   0.0   0.0  ...   NaN   NaN   NaN   NaN   NaN
#
#             WT17  WT18  WT21  WT22  WV01
# DATE
# 1970-01-01   NaN   NaN   NaN   NaN   NaN
# 1970-01-02   NaN   NaN   NaN   NaN   NaN
# 1970-01-03   NaN   1.0   NaN   NaN   NaN
# 1970-01-04   NaN   1.0   NaN   NaN   NaN
# 1970-01-05   NaN   NaN   NaN   NaN   NaN
# ...          ...   ...   ...   ...   ...
# 2022-10-17   NaN   NaN   NaN   NaN   NaN
# 2022-10-18   NaN   NaN   NaN   NaN   NaN
# 2022-10-19   NaN   NaN   NaN   NaN   NaN
# 2022-10-20   NaN   NaN   NaN   NaN   NaN
# 2022-10-21   NaN   NaN   NaN   NaN   NaN
#
# [19287 rows x 44 columns]

# %%
#clean data percentage of null values
null_pct = weather.isnull().sum() / weather.shape[0] * 100

# %%
null_pct
# Out:
# STATION     0.000000
# NAME        0.000000
# ACMH       50.147768
# ACSH       50.142583
# AWND       26.525639
# FMTM       47.508685
# PGTM       36.387204
# PRCP        0.000000
# SNOW        0.000000
# SNWD        0.010370
# TAVG       68.040649
# TMAX        0.000000
# TMIN        0.000000
# TSUN       99.839270
# WDF1       50.168507
# WDF2       49.867787
# WDF5       50.298128
# WDFG       73.448437
# WDFM       99.994815
# WESD       68.522839
# WSF1       50.152953
# WSF2       49.867787
# WSF5       50.303313
# WSFG       61.305543
# WSFM       99.994815
# WT01       63.021724
# WT02       93.503396
# WT03       93.327112
# WT04       98.257894
# WT05       98.112718
# WT06       99.061544
# WT07       99.440037
# WT08       79.696168
# WT09       99.274122
# WT11       99.927412
# WT13       88.671126
# WT14       95.401047
# WT15       99.782237
# WT16       65.899310
# WT17       99.688910
# WT18       93.949292
# WT21       99.974076
# WT22       99.745943
# WV01       99.994815
# dtype: float64

# %%
valid_columns= weather.columns[null_pct<.05]

# %%
valid_columns
# Out:
# Index(['STATION', 'NAME', 'PRCP', 'SNOW', 'SNWD', 'TMAX', 'TMIN'], dtype='object')

# %%
weather=weather[valid_columns].copy()

# %%
weather.columns=weather.columns.str.lower()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2022-10-17    67    54
# 2022-10-18    58    48
# 2022-10-19    56    43
# 2022-10-20    61    44
# 2022-10-21    64    43
#
# [19287 rows x 7 columns]

# %%
weather=weather.ffill()

# %%
weather.isnull().sum()
# Out:
# station    0
# name       0
# prcp       0
# snow       0
# snwd       0
# tmax       0
# tmin       0
# dtype: int64

# %%
weather.dtypes
# Out:
# station     object
# name        object
# prcp       float64
# snow       float64
# snwd       float64
# tmax         int64
# tmin         int64
# dtype: object

# %%
weather.index
# Out:
# Index(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04', '1970-01-05',
#        '1970-01-06', '1970-01-07', '1970-01-08', '1970-01-09', '1970-01-10',
#        ...
#        '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15', '2022-10-16',
#        '2022-10-17', '2022-10-18', '2022-10-19', '2022-10-20', '2022-10-21'],
#       dtype='object', name='DATE', length=19287)

# %%
weather.index=pd.to_datetime(weather.index)

# %%
weather.index
# Out:
# DatetimeIndex(['1970-01-01', '1970-01-02', '1970-01-03', '1970-01-04',
#                '1970-01-05', '1970-01-06', '1970-01-07', '1970-01-08',
#                '1970-01-09', '1970-01-10',
#                ...
#                '2022-10-12', '2022-10-13', '2022-10-14', '2022-10-15',
#                '2022-10-16', '2022-10-17', '2022-10-18', '2022-10-19',
#                '2022-10-20', '2022-10-21'],
#               dtype='datetime64[ns]', name='DATE', length=19287, freq=None)

# %%
weather.index.year
# Out:
# Index([1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970, 1970,
#        ...
#        2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022, 2022],
#       dtype='int32', name='DATE', length=19287)

# %%
weather.index.year.value_counts().sort_index()
# Out:
# DATE
# 1970    365
# 1971    365
# 1972    366
# 1973    365
# 1974    365
# 1975    365
# 1976    366
# 1977    365
# 1978    365
# 1979    365
# 1980    366
# 1981    365
# 1982    365
# 1983    365
# 1984    366
# 1985    365
# 1986    365
# 1987    365
# 1988    366
# 1989    365
# 1990    365
# 1991    365
# 1992    366
# 1993    365
# 1994    365
# 1995    365
# 1996    366
# 1997    365
# 1998    365
# 1999    365
# 2000    366
# 2001    365
# 2002    365
# 2003    365
# 2004    366
# 2005    365
# 2006    365
# 2007    365
# 2008    366
# 2009    365
# 2010    365
# 2011    365
# 2012    366
# 2013    365
# 2014    365
# 2015    365
# 2016    366
# 2017    365
# 2018    365
# 2019    365
# 2020    366
# 2021    365
# 2022    294
# Name: count, dtype: int64

# %%
weather["snwd"].plot()
# Out:
# <Axes: xlabel='DATE'>

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin
# DATE
# 1970-01-01    28    22
# 1970-01-02    31    22
# 1970-01-03    38    25
# 1970-01-04    31    23
# 1970-01-05    35    21
# ...          ...   ...
# 2022-10-17    67    54
# 2022-10-18    58    48
# 2022-10-19    56    43
# 2022-10-20    61    44
# 2022-10-21    64    43
#
# [19287 rows x 7 columns]

# %%
weather["target"]=weather.shift(-1)["tmax"]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43     NaN
#
# [19287 rows x 8 columns]

# %%
weather=weather.ffill()

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target
# DATE
# 1970-01-01    28    22    31.0
# 1970-01-02    31    22    38.0
# 1970-01-03    38    25    31.0
# 1970-01-04    31    23    35.0
# 1970-01-05    35    21    36.0
# ...          ...   ...     ...
# 2022-10-17    67    54    58.0
# 2022-10-18    58    48    56.0
# 2022-10-19    56    43    61.0
# 2022-10-20    61    44    64.0
# 2022-10-21    64    43    64.0
#
# [19287 rows x 8 columns]

# %%
from sklearn.linear_model import Ridge

# %%
rr=Ridge(alpha=.1)

# %%
predictors= weather.columns[~weather.columns.isin(["targer","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'target'], dtype='object')

# %%
def backtest(weather,model,predictors,start=3650,step=90):
  all_predictions=[]

  for i in range(start,weather.shape[0],step):
    train = weather.iloc[:i,:]
    test = weather.iloc[i:(i+step),:]

    model.fit(train[predictors],train["target"])
    preds = model.predict(test[predictors])
    preds=pd.Series(preds,index=test.index)
    combined =pd.concat([test["target"],preds],axis=1)

    combined.columns=["actual","prediction"]
    combined["diff"]=(combined["prediction"]-combined["actual"].abs())

    all_predictions.append(combined)

  return pd.concat(all_predictions)

# %%
predictions= backtest(weather,rr,predictors)

# %%
predictions
# Out:
#             actual  prediction          diff
# DATE
# 1979-12-30    43.0   43.000005  4.559387e-06
# 1979-12-31    42.0   42.000001  1.055630e-06
# 1980-01-01    41.0   41.000000  3.652581e-07
# 1980-01-02    36.0   36.000005  5.021399e-06
# 1980-01-03    30.0   30.000006  6.435912e-06
# ...            ...         ...           ...
# 2022-10-17    58.0   58.000001  1.150644e-06
# 2022-10-18    56.0   56.000001  5.439816e-07
# 2022-10-19    61.0   61.000000 -4.786081e-07
# 2022-10-20    64.0   63.999999 -5.082238e-07
# 2022-10-21    64.0   64.000000 -4.087615e-07
#
# [15637 rows x 3 columns]

# %%
from sklearn.metrics import mean_absolute_error

mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 1.2783926981640403e-06

# %%
predictions["diff"].mean()
# Out:
# -2.9699227804722817e-08

# %%
def pct_diff(old,new):
  return(new-old)/old


def compute_rolling(weather,horizon,col):
  label=f"rolling_{horizon}_{col}"

  weather[label]=weather[col].rolling(horizon).mean()
  weather[f"{label}_pct"]=pct_diff(weather[label],weather[col])
  return weather

rolling_horizons=[3,14]

for horizon in rolling_horizons:
  for col in ["tmax","tmin","prcp"]:
    weather=compute_rolling(weather,horizon,col)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-01  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-02  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-03  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-04  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-05  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-01    28    22    31.0             NaN                 NaN
# 1970-01-02    31    22    38.0             NaN                 NaN
# 1970-01-03    38    25    31.0       32.333333            0.175258
# 1970-01-04    31    23    35.0       33.333333           -0.070000
# 1970-01-05    35    21    36.0       34.666667            0.009615
# ...          ...   ...     ...             ...                 ...
# 2022-10-17    67    54    58.0       67.000000            0.000000
# 2022-10-18    58    48    56.0       63.666667           -0.089005
# 2022-10-19    56    43    61.0       60.333333           -0.071823
# 2022-10-20    61    44    64.0       58.333333            0.045714
# 2022-10-21    64    43    64.0       60.333333            0.060773
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-01             NaN                 NaN             NaN
# 1970-01-02             NaN                 NaN             NaN
# 1970-01-03       23.000000            0.086957        0.006667
# 1970-01-04       23.333333           -0.014286        0.006667
# 1970-01-05       23.000000           -0.086957        0.006667
# ...                    ...                 ...             ...
# 2022-10-17       51.000000            0.058824        0.026667
# 2022-10-18       51.333333           -0.064935        0.026667
# 2022-10-19       48.333333           -0.110345        0.026667
# 2022-10-20       45.000000           -0.022222        0.000000
# 2022-10-21       43.333333           -0.007692        0.000000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-01                 NaN              NaN                  NaN
# 1970-01-02                 NaN              NaN                  NaN
# 1970-01-03                 2.0              NaN                  NaN
# 1970-01-04                -1.0              NaN                  NaN
# 1970-01-05                -1.0              NaN                  NaN
# ...                        ...              ...                  ...
# 2022-10-17                 2.0        67.142857            -0.002128
# 2022-10-18                -1.0        67.285714            -0.138004
# 2022-10-19                -1.0        67.000000            -0.164179
# 2022-10-20                 NaN        65.928571            -0.074756
# 2022-10-21                 NaN        65.071429            -0.016465
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-01              NaN                  NaN              NaN
# 1970-01-02              NaN                  NaN              NaN
# 1970-01-03              NaN                  NaN              NaN
# 1970-01-04              NaN                  NaN              NaN
# 1970-01-05              NaN                  NaN              NaN
# ...                     ...                  ...              ...
# 2022-10-17        50.785714             0.063291         0.233571
# 2022-10-18        50.857143            -0.056180         0.135000
# 2022-10-19        50.000000            -0.140000         0.095714
# 2022-10-20        49.428571            -0.109827         0.095714
# 2022-10-21        48.500000            -0.113402         0.095714
#
#             rolling_14_prcp_pct
# DATE
# 1970-01-01                  NaN
# 1970-01-02                  NaN
# 1970-01-03                  NaN
# 1970-01-04                  NaN
# 1970-01-05                  NaN
# ...                         ...
# 2022-10-17            -0.657492
# 2022-10-18            -1.000000
# 2022-10-19            -1.000000
# 2022-10-20            -1.000000
# 2022-10-21            -1.000000
#
# [19287 rows x 20 columns]

# %%
weather=weather.iloc[14:,:]

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  \
# DATE
# 1970-01-15    29    13    36.0       29.666667           -0.022472
# 1970-01-16    36    21    43.0       30.333333            0.186813
# 1970-01-17    43    30    42.0       36.000000            0.194444
# 1970-01-18    42    25    25.0       40.333333            0.041322
# 1970-01-19    25    16    24.0       36.666667           -0.318182
# ...          ...   ...     ...             ...                 ...
# 2022-10-17    67    54    58.0       67.000000            0.000000
# 2022-10-18    58    48    56.0       63.666667           -0.089005
# 2022-10-19    56    43    61.0       60.333333           -0.071823
# 2022-10-20    61    44    64.0       58.333333            0.045714
# 2022-10-21    64    43    64.0       60.333333            0.060773
#
#             rolling_3_tmin  rolling_3_tmin_pct  rolling_3_prcp  \
# DATE
# 1970-01-15       18.000000           -0.277778        0.000000
# 1970-01-16       16.666667            0.260000        0.000000
# 1970-01-17       21.333333            0.406250        0.006667
# 1970-01-18       25.333333           -0.013158        0.040000
# 1970-01-19       23.666667           -0.323944        0.040000
# ...                    ...                 ...             ...
# 2022-10-17       51.000000            0.058824        0.026667
# 2022-10-18       51.333333           -0.064935        0.026667
# 2022-10-19       48.333333           -0.110345        0.026667
# 2022-10-20       45.000000           -0.022222        0.000000
# 2022-10-21       43.333333           -0.007692        0.000000
#
#             rolling_3_prcp_pct  rolling_14_tmax  rolling_14_tmax_pct  \
# DATE
# 1970-01-15                 NaN        29.857143            -0.028708
# 1970-01-16                 NaN        30.214286             0.191489
# 1970-01-17                 2.0        30.571429             0.406542
# 1970-01-18                 1.5        31.357143             0.339408
# 1970-01-19                -1.0        30.642857            -0.184149
# ...                        ...              ...                  ...
# 2022-10-17                 2.0        67.142857            -0.002128
# 2022-10-18                -1.0        67.285714            -0.138004
# 2022-10-19                -1.0        67.000000            -0.164179
# 2022-10-20                 NaN        65.928571            -0.074756
# 2022-10-21                 NaN        65.071429            -0.016465
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-15        18.857143            -0.310606         0.022857
# 1970-01-16        18.785714             0.117871         0.022857
# 1970-01-17        19.142857             0.567164         0.022857
# 1970-01-18        19.285714             0.296296         0.030000
# 1970-01-19        18.928571            -0.154717         0.030000
# ...                     ...                  ...              ...
# 2022-10-17        50.785714             0.063291         0.233571
# 2022-10-18        50.857143            -0.056180         0.135000
# 2022-10-19        50.000000            -0.140000         0.095714
# 2022-10-20        49.428571            -0.109827         0.095714
# 2022-10-21        48.500000            -0.113402         0.095714
#
#             rolling_14_prcp_pct
# DATE
# 1970-01-15            -1.000000
# 1970-01-16            -1.000000
# 1970-01-17            -0.125000
# 1970-01-18             2.333333
# 1970-01-19            -1.000000
# ...                         ...
# 2022-10-17            -0.657492
# 2022-10-18            -1.000000
# 2022-10-19            -1.000000
# 2022-10-20            -1.000000
# 2022-10-21            -1.000000
#
# [19273 rows x 20 columns]

# %%
weather = weather.fillna(0)

# %%
def expand_mean(df):
  return df.expanding(1).mean()
for col in ["tmax","tmin","prcp"]:
  weather[f"month_avg_{col}"]=weather[col].groupby(weather.index.month,group_keys=False).apply(expand_mean)
  weather[f"day_avg_{col}"]=weather[col].groupby(weather.index.day_of_year,group_keys=False).apply(expand_mean)

# %%
weather
# Out:
#                 station                              name  prcp  snow  snwd  \
# DATE
# 1970-01-15  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-16  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 1970-01-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.02   0.0   0.0
# 1970-01-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.10   0.0   0.0
# 1970-01-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# ...                 ...                               ...   ...   ...   ...
# 2022-10-17  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.08   0.0   0.0
# 2022-10-18  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-19  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-20  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
# 2022-10-21  USW00094789  JFK INTERNATIONAL AIRPORT, NY US  0.00   0.0   0.0
#
#             tmax  tmin  target  rolling_3_tmax  rolling_3_tmax_pct  ...  \
# DATE                                                                ...
# 1970-01-15    29    13    36.0       29.666667           -0.022472  ...
# 1970-01-16    36    21    43.0       30.333333            0.186813  ...
# 1970-01-17    43    30    42.0       36.000000            0.194444  ...
# 1970-01-18    42    25    25.0       40.333333            0.041322  ...
# 1970-01-19    25    16    24.0       36.666667           -0.318182  ...
# ...          ...   ...     ...             ...                 ...  ...
# 2022-10-17    67    54    58.0       67.000000            0.000000  ...
# 2022-10-18    58    48    56.0       63.666667           -0.089005  ...
# 2022-10-19    56    43    61.0       60.333333           -0.071823  ...
# 2022-10-20    61    44    64.0       58.333333            0.045714  ...
# 2022-10-21    64    43    64.0       60.333333            0.060773  ...
#
#             rolling_14_tmin  rolling_14_tmin_pct  rolling_14_prcp  \
# DATE
# 1970-01-15        18.857143            -0.310606         0.022857
# 1970-01-16        18.785714             0.117871         0.022857
# 1970-01-17        19.142857             0.567164         0.022857
# 1970-01-18        19.285714             0.296296         0.030000
# 1970-01-19        18.928571            -0.154717         0.030000
# ...                     ...                  ...              ...
# 2022-10-17        50.785714             0.063291         0.233571
# 2022-10-18        50.857143            -0.056180         0.135000
# 2022-10-19        50.000000            -0.140000         0.095714
# 2022-10-20        49.428571            -0.109827         0.095714
# 2022-10-21        48.500000            -0.113402         0.095714
#
#             rolling_14_prcp_pct  month_avg_tmax  month_avg_tmin  \
# DATE
# 1970-01-15            -1.000000       29.000000       13.000000
# 1970-01-16            -1.000000       32.500000       17.000000
# 1970-01-17            -0.125000       36.000000       21.333333
# 1970-01-18             2.333333       37.500000       22.250000
# 1970-01-19            -1.000000       35.000000       21.000000
# ...                         ...             ...             ...
# 2022-10-17            -0.657492       64.843462       50.225905
# 2022-10-18            -1.000000       64.839264       50.224540
# 2022-10-19            -1.000000       64.833844       50.220110
# 2022-10-20            -1.000000       64.831495       50.216299
# 2022-10-21            -1.000000       64.830986       50.211880
#
#             month_avg_prcp  day_avg_tmax  day_avg_tmin  day_avg_prcp
# DATE
# 1970-01-15        0.000000     29.000000     13.000000      0.000000
# 1970-01-16        0.000000     36.000000     21.000000      0.000000
# 1970-01-17        0.006667     43.000000     30.000000      0.020000
# 1970-01-18        0.030000     42.000000     25.000000      0.100000
# 1970-01-19        0.024000     25.000000     16.000000      0.000000
# ...                    ...           ...           ...           ...
# 2022-10-17        0.115316     63.490566     48.962264      0.114151
# 2022-10-18        0.115245     63.962264     48.943396      0.077170
# 2022-10-19        0.115175     62.056604     48.132075      0.117547
# 2022-10-20        0.115104     62.660377     48.471698      0.193962
# 2022-10-21        0.115034     63.471698     47.867925      0.079057
#
# [19273 rows x 26 columns]

# %%
predictors=weather.columns[~weather.columns.isin(["target","name","station"])]

# %%
predictors
# Out:
# Index(['prcp', 'snow', 'snwd', 'tmax', 'tmin', 'rolling_3_tmax',
#        'rolling_3_tmax_pct', 'rolling_3_tmin', 'rolling_3_tmin_pct',
#        'rolling_3_prcp', 'rolling_3_prcp_pct', 'rolling_14_tmax',
#        'rolling_14_tmax_pct', 'rolling_14_tmin', 'rolling_14_tmin_pct',
#        'rolling_14_prcp', 'rolling_14_prcp_pct', 'month_avg_tmax',
#        'month_avg_tmin', 'month_avg_prcp', 'day_avg_tmax', 'day_avg_tmin',
#        'day_avg_prcp'],
#       dtype='object')

# %%
 predictions = backtest(weather,rr,predictors)

# %%
mean_absolute_error(predictions["actual"],predictions["prediction"])
# Out:
# 4.792510527138959

# %%
predictions.sort_values("diff",ascending=False)
# Out:
#             actual  prediction       diff
# DATE
# 2014-01-06    20.0   42.589039  22.589039
# 2004-01-13    17.0   39.516309  22.516309
# 2019-01-20    15.0   36.823636  21.823636
# 2000-01-16    22.0   43.655611  21.655611
# 1990-03-23    37.0   57.971978  20.971978
# ...            ...         ...        ...
# 1985-04-18    84.0   58.425960 -25.574040
# 2003-04-15    86.0   59.432179 -26.567821
# 1998-03-26    80.0   51.966675 -28.033325
# 2007-03-26    78.0   49.965413 -28.034587
# 1990-03-12    85.0   54.361065 -30.638935
#
# [15623 rows x 3 columns]

# %%
predictions["diff"].round().value_counts().sort_index().plot()
# Out:
# <Axes: xlabel='diff'>
